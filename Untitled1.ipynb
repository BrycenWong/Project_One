# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

sns.set(style="ticks")

df = sns.load_dataset("iris")
df = pd.DataFrame(df)
sns.pairplot(df)

# %%
df = pd.read_csv('kc_house_data.txt')

sns.pairplot(df)
# Out:
# /Users/brycenwong/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/brycenwong/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
